# %%
import pandas as pd
df=pd.read_csv("Automobile_data.csv")

# %%
df
# Out:
#     index      company   body-style  wheel-base  length engine-type  \
# 0       0  alfa-romero  convertible        88.6   168.8        dohc
# 1       1  alfa-romero  convertible        88.6   168.8        dohc
# 2       2  alfa-romero    hatchback        94.5   171.2        ohcv
# 3       3         audi        sedan        99.8   176.6         ohc
# 4       4         audi        sedan        99.4   176.6         ohc
# ..    ...          ...          ...         ...     ...         ...
# 56     81   volkswagen        sedan        97.3   171.7         ohc
# 57     82   volkswagen        sedan        97.3   171.7         ohc
# 58     86   volkswagen        sedan        97.3   171.7         ohc
# 59     87        volvo        sedan       104.3   188.8         ohc
# 60     88        volvo        wagon       104.3   188.8         ohc
#
#    num-of-cylinders  horsepower  average-mileage    price
# 0              four         111               21  13495.0
# ...

# %%
df.drop(columns=df[["index"]],inplace=True)

# %%
df
# Out:
#         company   body-style  wheel-base  length engine-type num-of-cylinders  \
# 0   alfa-romero  convertible        88.6   168.8        dohc             four
# 1   alfa-romero  convertible        88.6   168.8        dohc             four
# 2   alfa-romero    hatchback        94.5   171.2        ohcv              six
# 3          audi        sedan        99.8   176.6         ohc             four
# 4          audi        sedan        99.4   176.6         ohc             five
# ..          ...          ...         ...     ...         ...              ...
# 56   volkswagen        sedan        97.3   171.7         ohc             four
# 57   volkswagen        sedan        97.3   171.7         ohc             four
# 58   volkswagen        sedan        97.3   171.7         ohc             four
# 59        volvo        sedan       104.3   188.8         ohc             four
# 60        volvo        wagon       104.3   188.8         ohc             four
#
# ...

# %%
df.shape
# Out:
# (61, 9)

# %%
df.describe()
# Out:
#        wheel-base      length  horsepower  average-mileage         price
# count   61.000000   61.000000   61.000000        61.000000     58.000000
# mean    98.481967  173.098361  107.852459        25.803279  15387.000000
# std      6.679234   14.021846   53.524398         8.129821  11320.259841
# min     88.400000  141.100000   48.000000        13.000000   5151.000000
# 25%     94.500000  159.100000   68.000000        19.000000   6808.500000
# 50%     96.300000  171.200000  100.000000        25.000000  11095.000000
# 75%    101.200000  177.300000  123.000000        31.000000  18120.500000
# max    120.900000  208.100000  288.000000        47.000000  45400.000000

# %%
df.corr()
# Out:
#                  wheel-base    length  horsepower  average-mileage     price
# wheel-base         1.000000  0.878381    0.463421        -0.547325  0.663085
# length             0.878381  1.000000    0.668555        -0.788429  0.788465
# horsepower         0.463421  0.668555    1.000000        -0.808804  0.901707
# average-mileage   -0.547325 -0.788429   -0.808804         1.000000 -0.770217
# price              0.663085  0.788465    0.901707        -0.770217  1.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 61 entries, 0 to 60
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   company           61 non-null     object
#  1   body-style        61 non-null     object
#  2   wheel-base        61 non-null     float64
#  3   length            61 non-null     float64
#  4   engine-type       61 non-null     object
#  5   num-of-cylinders  61 non-null     object
#  6   horsepower        61 non-null     int64
#  7   average-mileage   61 non-null     int64
#  8   price             58 non-null     float64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 4.4+ KB

# %%
df.isnull().sum()
# Out:
# company             0
# body-style          0
# wheel-base          0
# length              0
# engine-type         0
# num-of-cylinders    0
# horsepower          0
# average-mileage     0
# price               3
# dtype: int64

# %%
df1=df.dropna()

# %%
df1.isnull().sum()
# Out:
# company             0
# body-style          0
# wheel-base          0
# length              0
# engine-type         0
# num-of-cylinders    0
# horsepower          0
# average-mileage     0
# price               0
# dtype: int64

# %%
df1
# Out:
#           company   body-style  wheel-base  length engine-type  \
# 0     alfa-romero  convertible        88.6   168.8        dohc
# 1     alfa-romero  convertible        88.6   168.8        dohc
# 2     alfa-romero    hatchback        94.5   171.2        ohcv
# 3            audi        sedan        99.8   176.6         ohc
# 4            audi        sedan        99.4   176.6         ohc
# 5            audi        sedan        99.8   177.3         ohc
# 6            audi        wagon       105.8   192.7         ohc
# 7             bmw        sedan       101.2   176.8         ohc
# 8             bmw        sedan       101.2   176.8         ohc
# 9             bmw        sedan       101.2   176.8         ohc
# 10            bmw        sedan       103.5   189.0         ohc
# 11            bmw        sedan       103.5   193.8         ohc
# 12            bmw        sedan       110.0   197.0         ohc
# 13      chevrolet    hatchback        88.4   141.1           l
# ...

# %%
df1["company"].value_counts()
# Out:
# toyota           7
# bmw              6
# mazda            5
# nissan           5
# audi             4
# mercedes-benz    4
# mitsubishi       4
# volkswagen       4
# alfa-romero      3
# chevrolet        3
# honda            3
# jaguar           3
# dodge            2
# porsche          2
# volvo            2
# isuzu            1
# Name: company, dtype: int64

# %%
df1["body-style"].value_counts()
# Out:
# sedan          30
# hatchback      14
# wagon           9
# convertible     3
# hardtop         2
# Name: body-style, dtype: int64

# %%
df1["engine-type"].value_counts()
# Out:
# ohc      44
# dohc      5
# ohcv      5
# ohcf      2
# l         1
# rotor     1
# Name: engine-type, dtype: int64

# %%
df1["num-of-cylinders"].value_counts()
# Out:
# four      37
# six       11
# five       5
# eight      2
# three      1
# twelve     1
# two        1
# Name: num-of-cylinders, dtype: int64

# %%
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder = preprocessing.LabelEncoder()

# %%
df1["company"]= label_encoder.fit_transform(df1["company"])
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_2376\1749374925.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["company"]= label_encoder.fit_transform(df1["company"])

# %%
df1["body-style"]= label_encoder.fit_transform(df1["body-style"])
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_2376\2418430111.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["body-style"]= label_encoder.fit_transform(df1["body-style"])

# %%
df1["engine-type"]= label_encoder.fit_transform(df1["engine-type"])
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_2376\174036282.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["engine-type"]= label_encoder.fit_transform(df1["engine-type"])

# %%
df1["num-of-cylinders"]= label_encoder.fit_transform(df1["num-of-cylinders"])
# Out:
# C:\Users\dell\AppData\Local\Temp\ipykernel_2376\849501254.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df1["num-of-cylinders"]= label_encoder.fit_transform(df1["num-of-cylinders"])

# %%
df1
# Out:
#     company  body-style  wheel-base  length  engine-type  num-of-cylinders  \
# 0         0           0        88.6   168.8            0                 2
# 1         0           0        88.6   168.8            0                 2
# 2         0           2        94.5   171.2            4                 3
# 3         1           3        99.8   176.6            2                 2
# 4         1           3        99.4   176.6            2                 1
# 5         1           3        99.8   177.3            2                 1
# 6         1           4       105.8   192.7            2                 1
# 7         2           3       101.2   176.8            2                 2
# 8         2           3       101.2   176.8            2                 2
# 9         2           3       101.2   176.8            2                 3
# 10        2           3       103.5   189.0            2                 3
# ...

# %%
x=df1.drop(columns=df1[["price"]])

# %%
y=df1["price"]

# %%
y
# Out:
# 0     13495.0
# 1     16500.0
# 2     16500.0
# 3     13950.0
# 4     17450.0
# 5     15250.0
# 6     18920.0
# 7     16430.0
# 8     16925.0
# 9     20970.0
# 10    30760.0
# 11    41315.0
# 12    36880.0
# 13     5151.0
# 14     6295.0
# 15     6575.0
# 16     6377.0
# 17     6229.0
# 18     7295.0
# 19    12945.0
# 20    10345.0
# 21     6785.0
# 24    32250.0
# 25    35550.0
# 26    36000.0
# 27     5195.0
# 28     6095.0
# 29     6795.0
# 30    11845.0
# 31    18344.0
# 32    25552.0
# 33    28248.0
# 34    40960.0
# 35    45400.0
# 36     5389.0
# 37     6189.0
# 38     6989.0
# 39     8189.0
# 40     7099.0
# 41     6649.0
# 42     6849.0
# 43     7349.0
# 44    13499.0
# 45    34028.0
# 46    37028.0
# 48     5348.0
# 49     6338.0
# 50     6488.0
# 51     6918.0
# 52     7898.0
# 53     8778.0
# 54    15750.0
# 55     7775.0
# 56     7975.0
# 57     7995.0
# 58     9995.0
# 59    12940.0
# 60    13415.0
# Name: price, dtype: float64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.5)

# %%
x_train.shape
# Out:
# (29, 8)

# %%
y_train.shape
# Out:
# (29,)

# %%
x_test.shape
# Out:
# (29, 8)

# %%
y_test.shape
# Out:
# (29,)

# %%
import sklearn
from sklearn.linear_model import LinearRegression

# %%
lngr=LinearRegression()
lngr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=lngr.predict(x_test)

# %%
y_predict
# Out:
# array([  9711.54361934,   7322.91504545,   9803.65217024,  30867.24094829,
#         17852.51117975,   6968.04105289,  28700.68391172,  14258.03839323,
#         10878.44516953,  13401.36471386,  17127.80359662, -12955.86621658,
#         14235.03661773,  24654.46671709,  33352.80494708,  13284.10726846,
#          6300.84107791,   3927.3819084 ,   7221.07954643,  27886.34842967,
#         28599.49604174,  10854.91445213,   5720.28945032,  10321.26282729,
#         37028.16217381,  18433.59007161,   7221.07954643,  29412.16819343,
#         36652.45952715])

# %%
lngr.intercept_
# Out:
# -25325.558903608733

# %%
lngr.coef_
# Out:
# array([   59.14566543,   445.32325104,   371.49349117,  -148.57241918,
#        -2313.59855647, -3923.76117602,   285.08014501,   413.45618747])

# %%
from sklearn.metrics import r2_score,mean_squared_error
import numpy as np

# %%
print("R2 score",r2_score(y_test,y_predict))
print("RMSE",np.sqrt(mean_squared_error(y_test,y_predict)))
# Out:
# R2 score 0.6875486634846864
# RMSE 6943.9794220515805

# %%
from sklearn.linear_model import Lasso
R=Lasso(alpha=100000)

# %%
R.fit(x_train,y_train)
# Out:
# Lasso(alpha=100000)

# %%
print(R.coef_)
print(R.intercept_)
# Out:
# [ -0.          0.          0.          0.         -0.         -0.
#  140.1811882  -0.       ]
# -450.914552465998

# %%
y_pred1=R.predict(x_test)
print("R2 score",r2_score(y_test,y_pred1))
print("RMSE",np.sqrt(mean_squared_error(y_test,y_pred1)))
# Out:
# R2 score 0.6854612222425891
# RMSE 6967.136659494136

# %%
import matplotlib.pyplot as plt

# %%
m = 100
x1 = 5 * np.random.rand(m, 1) - 2
x2 = 0.7 * x1 ** 2 - 2 * x1 + 3 + np.random.randn(m, 1)

plt.scatter(x1, x2)
plt.show()

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures

def get_preds_ridge(x1, x2, alpha):
    model = Pipeline([
        ('poly_feats', PolynomialFeatures(degree=16)),
        ('ridge', Lasso(alpha=alpha))
    ])
    model.fit(x1, x2)
    return model.predict(x1)

alphas = [0, 20, 200]
cs = ['r', 'g', 'b']

plt.figure(figsize=(10, 6))
plt.plot(x1, x2, 'b+', label='Datapoints')

for alpha, c in zip(alphas, cs):
    preds = get_preds_ridge(x1, x2, alpha)
    # Plot
    plt.plot(sorted(x1[:, 0]), preds[np.argsort(x1[:, 0])], c, label='Alpha: {}'.format(alpha))

plt.legend()
plt.show()
# Out:
# c:\Users\dell\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\pipeline.py:382: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   self._final_estimator.fit(Xt, y, **fit_params_last_step)
# c:\Users\dell\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:648: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# ...
